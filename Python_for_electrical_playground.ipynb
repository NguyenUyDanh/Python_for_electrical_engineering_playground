# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenUyDanh/Python_for_electrical_engineering_playground/blob/main/Python_for_electrical_playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 4
a = x*x + 2*x + 5
print(a)
# Out:
# 29
